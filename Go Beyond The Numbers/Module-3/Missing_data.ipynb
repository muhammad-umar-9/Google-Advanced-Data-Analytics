# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('eda_missing_data_dataset1.csv')
df.head()
# Out:
#          date  center_point_geom  longitude  latitude  number_of_strikes
# 0  2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                 48
# 1  2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                 32
# 2  2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                118
# 3  2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                 69
# 4  2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                 44

# %%
df.shape
# Out:
# (717530, 5)

# %%
df_zip = pd.read_csv('eda_missing_data_dataset2.csv')
df_zip.head()
# Out:
#          date  zip_code                                 city          state  \
# 0  2018-08-08      3281                                Weare  New Hampshire
# 1  2018-08-14      6488                 Heritage Village CDP    Connecticut
# 2  2018-08-16     97759  Sisters city, Black Butte Ranch CDP         Oregon
# 3  2018-08-18      6776                      New Milford CDP    Connecticut
# 4  2018-08-08      1077                            Southwick  Massachusetts
#
#   state_code   center_point_geom  number_of_strikes
# 0         NH   POINT(-71.7 43.1)                  1
# 1         CT   POINT(-73.2 41.5)                  3
# 2         OR  POINT(-121.4 44.3)                  3
# 3         CT   POINT(-73.4 41.6)                 48
# 4         MA     POINT(-72.8 42)                  2

# %%
df_zip.shape
# Out:
# (323700, 7)

# %%
df_joined = df.merge(df_zip, how='left', on=['date' , 'center_point_geom'])
df_joined.head()
# Out:
#          date  center_point_geom  longitude  latitude  number_of_strikes_x  \
# 0  2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                   48
# 1  2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                   32
# 2  2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                  118
# 3  2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                   69
# 4  2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                   44
#
#    zip_code city state state_code  number_of_strikes_y
# 0       NaN  NaN   NaN        NaN                  NaN
# 1       NaN  NaN   NaN        NaN                  NaN
# 2       NaN  NaN   NaN        NaN                  NaN
# 3       NaN  NaN   NaN        NaN                  NaN
# 4       NaN  NaN   NaN        NaN                  NaN

# %%
df_joined.describe()
# Out:
#            longitude       latitude  number_of_strikes_x       zip_code  \
# count  717530.000000  717530.000000        717530.000000  323700.000000
# mean      -90.875445      33.328572            21.637081   57931.958996
# std        13.648429       7.938831            48.029525   22277.327411
# min      -133.900000      16.600000             1.000000    1002.000000
# 25%      -102.800000      26.900000             3.000000   38260.750000
# 50%       -90.300000      33.200000             6.000000   59212.500000
# 75%       -80.900000      39.400000            21.000000   78642.000000
# max       -43.800000      51.700000          2211.000000   99402.000000
#
#        number_of_strikes_y
# count        323700.000000
# mean             25.410587
# std              57.421824
# min               1.000000
# 25%               3.000000
# 50%               8.000000
# 75%              24.000000
# max            2211.000000

# %%
missing_values = pd.isnull(df_joined.state_code)
missing_values.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: state_code, dtype: bool

# %%
df_null_geo = df_joined[missing_values]
df_null_geo.head()
# Out:
#          date  center_point_geom  longitude  latitude  number_of_strikes_x  \
# 0  2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                   48
# 1  2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                   32
# 2  2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                  118
# 3  2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                   69
# 4  2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                   44
#
#    zip_code city state state_code  number_of_strikes_y
# 0       NaN  NaN   NaN        NaN                  NaN
# 1       NaN  NaN   NaN        NaN                  NaN
# 2       NaN  NaN   NaN        NaN                  NaN
# 3       NaN  NaN   NaN        NaN                  NaN
# 4       NaN  NaN   NaN        NaN                  NaN

# %%
df_null_geo.shape
# Out:
# (393830, 10)

# %%
top_missing = df_null_geo[['latitude' , 'longitude' , 'number_of_strikes_x']].groupby(['latitude' , 'longitude']).sum().sort_values('number_of_strikes_x' , ascending=False).reset_index()

# %%
top_missing.head(10)
# Out:
#    latitude  longitude  number_of_strikes_x
# 0      22.4      -84.2                 3841
# 1      22.9      -82.9                 3184
# 2      22.4      -84.3                 2999
# 3      22.9      -83.0                 2754
# 4      22.5      -84.1                 2746
# 5      22.5      -84.2                 2738
# 6      22.3      -81.0                 2680
# 7      22.9      -82.4                 2652
# 8      22.9      -82.3                 2618
# 9      22.3      -84.3                 2551

# %%
import plotly.express as px  # Be sure to import express
# reduce size of db otherwise it could break
fig = px.scatter_geo(top_missing[top_missing.number_of_strikes_x>=300],  # Input Pandas DataFrame
                    lat="latitude",  # DataFrame column with latitude
                    lon="longitude",  # DataFrame column with latitude
                    size="number_of_strikes_x") # Set to plot size as number of strikes
fig.update_layout(
    title_text = 'Missing data', # Create a Title
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5c0aff40-0734-4ae6-b137-513c6dbf137c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c0aff40-0734-4ae6-b137-513c6dbf137c")) {                    Plotly.newPlot(                        "5c0aff40-0734-4ae6-b137-513c6dbf137c",                        [{"geo":"geo","hovertemplate":"number_of_strikes_x=%{marker.size}\u003cbr\u003elatitude=%{lat}\u003cbr\u003elongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[22.4,22.9,22.4,22.9,22.500000000000004,22.500000000000004,22.3,22.9,22.9,22.300000000000004,23.0,22.6,22.600000000000005,23.0,22.9,23.0,22.9,22.600000000000005,22.300000000000004,22.399999999999995,22.399999999999995,29.300000000000004,23.0,23.0,22.4,22.3,22.3,22.9,22.4,22.2,22.9,22.3,21.3,22.3,22.3,22.500000000000004,23.0,22.8,23.000000000000004,22.3,22.4,23.000000000000004,22.8,21.7,22.3,21.8,20.300000000000004,22.3,23.1,22.3,22.4,21.7,26.3,22.9,22.4,22.8,22.300000000000004,22.1,22.300000000000004,22.399999999999995,22.500000000000004,22.2,22.600000000000005,22.2,22.399999999999995,22.2,22.600000000000005,23.0,22.3,20.200000000000003,22.9,22.600000000000005,22.2,22.2,23.1,21.200000000000003,21.9,23.1,26.3,26.5,22.5,23.0,22.2,22.3,28.399999999999995,22.8,22.600000000000005,22.9,26.1,22.4,22.5,22.5,22.0,22.5,23.1,26.300000000000004,22.500000000000004,27.2,22.4,22.500000000000004,23.0,26.899999999999995,22.8,30.499999999999996,22.4,23.1,27.6,22.7
.600000000000005,23.1,22.600000000000005,30.2,26.7,22.1,27.2,28.4,28.6,22.300000000000004,22.9,30.4,36.9,22.000000000000004,26.1,26.8,21.0,22.4,22.0,18.2,28.8,20.1,21.9,30.6,28.6,27.0,30.300000000000004,20.1,22.500000000000004,43.2,22.500000000000004,29.300000000000004,20.3,23.1,22.2,29.200000000000003,26.3,22.300000000000004,24.000000000000004,23.8,30.5,22.8,29.1,29.200000000000003,26.8,27.800000000000004,26.9,25.8,22.7,21.5,22.0,20.2,28.0,22.600000000000005,30.499999999999996,20.9,23.0,27.7,22.2,21.7,26.3,30.300000000000004,31.0,28.6,28.600000000000005,22.600000000000005,22.0,26.3,22.8,22.500000000000004,22.1,22.500000000000004,26.4,22.9,26.0,25.9,27.7,22.1,20.1,35.8,21.5,27.5,26.1,22.9,18.3,27.4,22.7,28.0,26.7,26.9,22.4,23.0,27.1,22.8,27.3,22.600000000000005,21.700000000000003,18.200000000000003,26.999999999999996,26.3,26.2,27.8,22.3,22.7,21.800000000000004,43.3,30.60 ...

# %% [markdown]
# **Merge Function Explanation**

# %%
one_data = {
    'Planets': ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn',  'Neptune'],
    'Distance from Sun': [57.9, 108.2, 149.6, 227.9, 778.6, 1433.5,  449],
    'Moons': [0, 0, 1, 2, 79, 82, 27]
}
df_1 = pd.DataFrame(one_data)
df_1
# Out:
#    Planets  Distance from Sun  Moons
# 0  Mercury               57.9      0
# 1    Venus              108.2      0
# 2    Earth              149.6      1
# 3     Mars              227.9      2
# 4  Jupiter              778.6     79
# 5   Saturn             1433.5     82
# 6  Neptune              449.0     27

# %%
two_Data = {
    'planets' : ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter',  'Uranus', 'Neptune'],
    'Distance from Sun': [57.9, 108.2, 149.6, 227.9, 778.6, 1433,  449.6 ],
    'Moons': [0, 0, 1, 2, 79, 82, 27],
    'Planet Type': ['Terrestrial', 'Terrestrial', 'Terrestrial', 'Terrestrial', 'Gas Giant', 'Gas Giant',  'Ice Giant']
}
df_2 = pd.DataFrame(two_Data)
df_2
# Out:
#    planets  Distance from Sun  Moons  Planet Type
# 0  Mercury               57.9      0  Terrestrial
# 1    Venus              108.2      0  Terrestrial
# 2    Earth              149.6      1  Terrestrial
# 3     Mars              227.9      2  Terrestrial
# 4  Jupiter              778.6     79    Gas Giant
# 5   Uranus             1433.0     82    Gas Giant
# 6  Neptune              449.6     27    Ice Giant

# %%
merge_data = df_1.merge(df_2, how='left', on = ['Moons' , 'Distance from Sun' ])
merge_data
# Out:
#    Planets  Distance from Sun  Moons  planets  Planet Type
# 0  Mercury               57.9      0  Mercury  Terrestrial
# 1    Venus              108.2      0    Venus  Terrestrial
# 2    Earth              149.6      1    Earth  Terrestrial
# 3     Mars              227.9      2     Mars  Terrestrial
# 4  Jupiter              778.6     79  Jupiter    Gas Giant
# 5   Saturn             1433.5     82      NaN          NaN
# 6  Neptune              449.0     27      NaN          NaN
